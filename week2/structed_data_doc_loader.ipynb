# %%
from langchain_community.document_loaders import CSVLoader, DataFrameLoader, JSONLoader

csv_loader = CSVLoader(
  file_path = "./libs/002/iris.csv",
  encoding = "utf-8",
)

csv_docs = csv_loader.load()

csv_doc = csv_docs[0]

for row in csv_doc:
  print(type(row))
  print(row.metadata)
  print(row.page_content)
# Out:
# <class 'tuple'>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 14
#      10 csv_doc = csv_docs[0]
#      11
#      12 for row in csv_doc:
#      13   print(type(row))
# ---> 14   print(row.metadata)
#      15   print(row.page_content)
#      16
#
# AttributeError: 'tuple' object has no attribute 'metadata'

# %%
# %pip install -Uq tqdm
# Out:
# Note: you may need to restart the kernel to use updated packages.
