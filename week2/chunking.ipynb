# %%
# %pip install -Uq langchain-text-splitters langchain-community
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

with open("../libs/003/split_text.txt", encoding="utf-8") as f:
    text = f.read()

# 기본 분할 순서
# 개행문자
# 1단계: '\n\n'
# 2단계: '\n'
# 3단계: '.'
# 4단계: ' '
# 5단계: ''

splitter = RecursiveCharacterTextSplitter(
    separators=["\n\n", "\n", ".", " ", ""],
    chunk_size=40,
    chunk_overlap=10,
    length_function=len,
)

chunk_sentences = splitter.split_text(text)
print(chunk_sentences)
# Out:
# ['머신러닝은 데이터로부터 스스로 학습하는 기술입니다', '. 지도 학습은 레이블 데이터를 사용합니다.', '비지도 학습은 레이블 없이 구조를 찾습니다', '. 강화 학습은 보상을 통해 학습합니다.', '딥러닝은 신경망을 여러 층으로 쌓아 학습합니다', '. 자연어 처리는 텍스트를 이해하는 기술입니다.']

# %%
from langchain_text_splitters import CharacterTextSplitter
from langchain_community.document_loaders import TextLoader

# step 1.
loader = TextLoader(
    file_path="../libs/003/split_text.txt",
    encoding="utf-8",
)

doc = loader.load()[0]

splitter = CharacterTextSplitter(
    separator="\n\n",
    chunk_size=80,
    chunk_overlap=10,
    length_function=len,
)

chunk_paragraph = splitter.split_text(doc.page_content)

print(chunk_paragraph)
# Out:
# ['머신러닝은 데이터로부터 스스로 학습하는 기술입니다. 지도 학습은 레이블 데이터를 사용합니다.\n비지도 학습은 레이블 없이 구조를 찾습니다. 강화 학습은 보상을 통해 학습합니다.\n딥러닝은 신경망을 여러 층으로 쌓아 학습합니다. 자연어 처리는 텍스트를 이해하는 기술입니다.']

# %%
splitter = CharacterTextSplitter(
    separator="",
    chunk_size=10,
    chunk_overlap=5,
)

chunks = splitter.split_text(doc.page_content)
print(chunks)
# Out:
# ['머신러닝은 데이터로', '데이터로부터 스스', '부터 스스로 학습하', '로 학습하는 기술입', '는 기술입니다. 지', '니다. 지도 학습은', '도 학습은 레이블', '레이블 데이터를', '데이터를 사용합니다', '사용합니다.\n비지도', '.\n비지도 학습은', '학습은 레이블 없', '레이블 없이 구조를', '이 구조를 찾습니다', '찾습니다. 강화', '. 강화 학습은 보', '학습은 보상을 통해', '상을 통해 학습합니', '학습합니다.\n딥러', '다.\n딥러닝은 신경', '닝은 신경망을 여러', '망을 여러 층으로', '층으로 쌓아 학습', '쌓아 학습합니다.', '합니다. 자연어 처', '자연어 처리는 텍스', '리는 텍스트를 이해', '트를 이해하는 기술', '하는 기술입니다.']

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

splitter = RecursiveCharacterTextSplitter(
  separators=["\n\n", "\n"],
  chunk_size=10,
  chunk_overlap=5,
  length_function=len,
)

chunks = splitter.split_text(doc.page_content)
print(chunks)
# Out:
# ['머신러닝은 데이터로부터 스스로 학습하는 기술입니다. 지도 학습은 레이블 데이터를 사용합니다.', '\n비지도 학습은 레이블 없이 구조를 찾습니다. 강화 학습은 보상을 통해 학습합니다.', '\n딥러닝은 신경망을 여러 층으로 쌓아 학습합니다. 자연어 처리는 텍스트를 이해하는 기술입니다.']

# %%
# %pip install -Uq langchain-experimental
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
#Semantic Chunking

from langchain_experimental.text_splitter import SemanticChunker
from langchain_ollama import ChatOllama

TEXT = """
머신러닝은 데이터로부터 패턴을 학습하는 기술입니다.
지도 학습은 정답이 있는 데이터를 사용합니다.
비지도 학습은 데이터의 구조를 발견합니다.

자동차 엔진은 연료를 연소하여 에너지를 생성합니다.
내연기관은 연료를 폭발시켜 동력을 얻습니다.
전기차는 배터리를 사용하여 모터를 구동합니다.
"""
