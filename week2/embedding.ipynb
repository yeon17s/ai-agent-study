# %%
# %pip install -Uq langchain langchain-core langchain-ollama langchain-openai
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_ollama.embeddings import OllamaEmbeddings

# nomic-embed-text-v2-moe
model = OllamaEmbeddings(
  model="nomic-embed-text-v2-moe",
)

# embed_documents()
# embed_query()

vector = model.embed_query("비행기")
print(len(vector))
# Out:
# 768

# %%
docs = [ "안녕하세요!", "반갑습니다."]

vectors = model.embed_documents(docs)
print(vectors[0][1:5], vectors[1][1:5])
# Out:
# [-0.008651527, 0.030629288, -0.042873006, 0.03076903] [0.010062584, 0.008423951, 0.00408083, 0.018114856]
