# %% [markdown]
# ### Runnable 인터페이스

# %%
# 동기 방식

from langchain_core.runnables import RunnableLambda

# def append_ten(target: int) -> int:
#     return target + 10
append_ten = lambda x: x + 10

result = append_ten(10)
print(f'result = {result}') 

run_append = RunnableLambda(append_ten) #Runnable

# multiply_two = lambda x: x * 2
run_multiply = RunnableLambda(lambda x: x * 2) #Runnable

append_result = run_append.invoke(5)
print(f'append_result = {append_result}')

multiply_result = run_multiply.invoke(append_result)
print(f'multiply_result = {multiply_result}')

other_result = run_multiply.invoke(
  run_append.invoke(10)
)
print(f'other_result = {other_result}')
# Out:
# result = 20
# append_result = 15
# multiply_result = 30
# other_result = 40

# %%
# %pip install -Uq nest_asyncio
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import asyncio #비동기 방식
import time # 시간 측정

import nest_asyncio
nest_asyncio.apply() # Jupyter Notebook에서 asyncio를 사용할 수 있도록 설정

from langchain_core.runnables import RunnableLambda

# lambda 함수는 async로 정의할 수 없으므로, 일반 함수를 정의하여 RunnableLambda에 전달
async def append_ten(x: int) -> int:
  print(f'{x}를 받아서 append_ten 시작!')
  await asyncio.sleep(2)
  print(f'{x}를 받아서 append_ten 종료!')
  return x + 10

run_async_append = RunnableLambda(append_ten)

#   동기 / 비동기 
# invoke / ainvoke
# batch  / abatch
# stream / astream

async def main():
  start = time.time() # 시작 시간 측정
  results = await asyncio.gather(
    run_async_append.ainvoke(5),
    run_async_append.ainvoke(3),
    run_async_append.ainvoke(8)
  )
  end = time.time() # 종료 시간 측정

  print('결과 ', results)
  print('총 실행시간', round(end - start, 2), '초')

asyncio.run(main())
# Out:
# 5를 받아서 append_ten 시작!
# 3를 받아서 append_ten 시작!
# 8를 받아서 append_ten 시작!
# 5를 받아서 append_ten 종료!
# 3를 받아서 append_ten 종료!
# 8를 받아서 append_ten 종료!
# 결과  [15, 13, 18]
# 총 실행시간 2.0 초

# %%
# langchain
# langchain-core
# langchain-community

# langgraph

# Runnable
# RunnableLambda

from langchain_core.runnables import RunnableLambda

append_ten = lambda x: x + 10

run_append = RunnableLambda(append_ten) #Runnable
run_multiply = RunnableLambda(lambda x: x * 2) #Runnable

arr1 = [ 2, 4, 6 ] # = [ _ for _ in range(2, 8, 2) ]
arr2 = [ 3, 5, 7 ]

result1: list[int] = run_append.batch(arr1)

for result in result1:
  print(f'결과: {result}')

print()
# Out:
# append_ten 결과: 12
# append_ten 결과: 14
# append_ten 결과: 16

# %%
# stream

from langchain_core.runnables import RunnableLambda

import time

def print_str(data: str):
  for _ in data:
    time.sleep(0.3)
    yield _ 

run_print_str = RunnableLambda(print_str)
for _ in run_print_str.stream('안녕하세요 여러분! 반갑습니다! stream() 메서드를 살펴봅시다.'):
  print(_, end='', flush=True)
# Out:
# 안녕하세요 여러분! 반갑습니다! stream() 메서드를 살펴봅시다.
