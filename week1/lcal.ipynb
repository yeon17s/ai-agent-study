# %%
# 프롬프트 -> 모델 -> 파싱(문자열)

from dotenv import load_dotenv
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

prompt = ChatPromptTemplate.from_messages([
  ("system", "너는 관광 가이드 역할을 수행할거야. 한국어로 대답해줘."),
  ("human", "{country}의 {city}에서 가장 유명한 {target}을 3개 소개해줘.")
])

model = ChatOpenAI(
  model = "gpt-5-mini",
  temperature = 0
)

parser = StrOutputParser()

chain = prompt | model | parser

result = chain.invoke({
  'country': '대한민국',
  'city': '대전',
  'target': '관광지'
})

print(result)
# Out:
# /Users/yeon/Project/knu-python/venv/lib/python3.14/site-packages/langchain_core/_api/deprecation.py:25: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1
# 좋습니다 — 대전에서 가장 유명하고 여행객에게 인기 있는 관광지 3곳을 간단히 소개할게요.
#
# 1) 유성온천(유성온천지구)
# - 개요: 대전의 대표 온천 지역으로 옛날부터 온천문화가 발달한 곳입니다. 족욕장과 찜질방, 호텔 스파 등 다양한 온천 시설을 즐길 수 있어 휴식 여행에 최적입니다.
# - 볼거리/체험: 공중 족욕장, 전통 온천탕·스파, 주변 카페와 먹거리 골목.
# - 팁: 저녁 시간대가 분위기 좋고 주말엔 붐빕니다. 개인 수건·편안한 복장 준비. 반나절~하루 추천.
#
# 2) 대전엑스포과학공원(한빛탑) 및 국립중앙과학관 인근
# - 개요: 1993년 대전엑스포 개최지로 조성된 공원으로, 상징 탑인 한빛탑과 과학전시 시설이 모여 있습니다. 가족·청소년에게 인기 있는 과학 체험 공간입니다.
# - 볼거리/체험: 한빛탑 전경·야경, 과학 전시·체험관, 주기적 이벤트와 전시. 근처에 국립중앙과학관이 있어 함께 둘러보기 좋습니다.
# - 팁: 낮에는 전시 관람, 해질녘엔 한빛탑 야경 추천. 주차와 대중교통 접근성 양호. 2~4시간 권장.
#
# 3) 대전 오월드 (O-World)
# - 개요: 동물원·식물원·놀이공원이 합쳐진 복합 테마파크로 아이들과 가족 여행객에게 매우 인기입니다. 계절별 꽃 축제와 다양한 공연이 열립니다.
# - 볼거리/체험: 동물 사파리·펫팅존, 놀이기구, 계절별 꽃정원(벚꽃·장미 등).
# - 팁: 하루 코스로 여유있게 즐기기 좋고, 온라인 예매로 할인받을 수 있음. 주말·성수기 혼잡 예상.
#
# 더 원하시면 각 장소의 상세 교통편(지하철·버스·주차), 운영시간·요금, 추천 식당을 더 알려드릴게요. 어느 곳부터 자세히 알고 싶으세요?
