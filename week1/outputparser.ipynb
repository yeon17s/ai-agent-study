# %% [markdown]
# - StrOutputParser
# - JsonOutputParser (unicode 사용)
# - PydanticOutputParser (pydantic: 파이썬에서 데이터클래스 생성 가능)
# - CommaSeparatorOutputParser
# - ListOutputParser
# - StructuredOutputParser -> with_structed_output

# %%
# %pip install -Uq langchain-openai dotenv
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv

load_dotenv()

model = ChatOpenAI(
  model="gpt-5-mini"
)

prompt = ChatPromptTemplate.from_messages([
    ("human", "대전에 대해서 100글자로 설명해줘.")
])

parser = StrOutputParser()

# msg = prompt.invoke({})

result = model.invoke(prompt.invoke({}))

parsed = parser.invoke(result)

print(parsed)
# Out:
#   Cell In[3], line 12
#     (human")
#           ^
# SyntaxError: unterminated string literal (detected at line 12)

# %%
# 모델의 응답을 파서를 통해서 살펴볼 예정
# 일반적인 랭체인: 프롬프트 -> 모델 -> 파서 
# prompt | model | parser
