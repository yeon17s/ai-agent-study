# %%
# %pip install -Uq langchain_openai dotenv
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(
  model="gpt-5-mini"
)

# %%
llm.invoke("대전은 어떤 곳이야?")
# Out:
# AIMessage(content='대전은 대한민국의 중부에 위치한 광역시로, 한마디로 말하면 ‘과학·교육의 도시’이자 교통의 요충지예요. 주요 특징을 정리하면 다음과 같습니다.\n\n- 위치와 규모: 충청권 중심 도시로 서울·대구·대전·광주를 잇는 중부권 교통의 요지. 인구는 대략 140만~150만명 수준입니다.  \n- 과학·연구 허브: 대덕연구개발특구(대덕특구)와 KAIST 등 연구·대학 기관이 모여 있어 연구개발과 스타트업 중심지로 알려져 있어요.  \n- 교육 환경: KAIST, 충남대학교 등 주요 대학이 있어 학생과 연구자가 많습니다.  \n- 교통: KTX가 정차해 전국 이동이 편리하고, 도시 내부는 대전 지하철과 버스가 잘 연결되어 있습니다.  \n- 관광·휴식지: 유성온천, 한밭수목원, 엑스포과학공원, 대전시립미술관, 오월드(테마파크) 등 가족 단위로 즐길 곳이 많아요.  \n- 생활비·주거: 서울보다 집값과 생활비가 비교적 낮고, 주거환경은 전반적으로 쾌적합니다.  \n- 기후: 사계절이 뚜렷해 여름은 덥고 습한 편, 겨울은 비교적 춥습니다.  \n- 분위기: 대체로 조용하고 안정적인 분위기—학생·연구원·가족 단위 거주자가 많은 편입니다.\n\n더 구체적으로 알고 싶은 내용 있나요? (예: 관광 코스, 이사·주거 정보, 대학·취업 환경 등)', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1241, 'prompt_tokens': 14, 'total_tokens': 1255, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 832, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tok
# ...
